# %% [markdown]
# ## Load libraries

# %%
library(RColorBrewer)
library(plyr)
library(dplyr)
library(ggplot2)
library(reshape)
library(reshape2)
library(tidyverse)
library(data.table)
library(Rtsne)
library(ggrepel)
library(repr)

theme_nogrid = function(...) theme_bw() + theme(axis.line = element_line(colour = "black"),
                            panel.grid.major = element_blank(),
                             panel.grid.minor = element_blank(),
                             panel.background = element_blank())
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘reshape’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     rename
#
#
# The following objects are masked from ‘package:plyr’:
#
#     rename, round_any
#
#
#
# Attaching package: ‘reshape2’
#
#
# The following objects are masked from ‘package:reshape’:
#
#     colsplit, melt, recast
#
#
# ── Attaching packages ────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ tibble  3.1.8     ✔ purrr   0.3.5
# ✔ tidyr   1.2.1     ✔ stringr 1.5.0
# ✔ readr   2.1.3     ✔ forcats 0.5.2
# ── Conflicts ───────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()   masks plyr::arrange()
# ✖ purrr::compact()   masks plyr::compact()
# ✖ dplyr::count()     masks plyr::count()
# ✖ tidyr::expand()    masks reshape::expand()
# ✖ dplyr::failwith()  masks plyr::failwith()
# ✖ dplyr::filter()    masks stats::filter()
# ✖ dplyr::id()        masks plyr::id()
# ✖ dplyr::lag()       masks stats::lag()
# ✖ dplyr::mutate()    masks plyr::mutate()
# ✖ reshape::rename()  masks dplyr::rename(), plyr::rename()
# ✖ dplyr::summarise() masks plyr::summarise()
# ✖ dplyr::summarize() masks plyr::summarize()
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# The following objects are masked from ‘package:reshape2’:
#
#     dcast, melt
#
#
# The following object is masked from ‘package:reshape’:
#
#     melt
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last

# %% [markdown]
# ## Set paths to reference files

# %%
cancers=c('ccRCC','CRC','CESC','HNSCC','UCEC','GBM','BRCA','OV','MM','PDAC','BRCA_Basal','MM','OV')

#ATAC project color scales
path_to_ATAC_colors='../data/Colors_panatac_v2.0.rds'

#Matrix with accessibility averaged per tumor cells from each sample, and per normal cells from tissue
path_to_ATAC_average_matrix='../data/snATAC/Average_accessibility_matrix.DataSlot.20230212.tsv'

#Cell counts per each cell group in matrix with average ATAC accessibility
path_to_ATAC_average_matrix_meta='../data/snATAC/Cell_count_perGroup.forAverageAccessibilityMatrix.20230212.tsv'

#ATAC catalog
path_to_ATAC_catalog='../data/ATAC_catalog.20220114.v2.txt'

#Tissue- and cancer-specific DACRs plotted in 1d, Supplementary Table S2c
path_to_ATAC_DACRs_1d='../data/snATAC/Table_S2c_selected_tiss_cancer_DACRs.txt'

# %% [markdown]
# ## Set color scales

# %%
cols=readRDS(path_to_ATAC_colors)
dis_cols_ed <- cols$Cancer
dis_cols_ed=c('#C69158',dis_cols_ed)
names(dis_cols_ed)[1]='CEAD'

# %%
#Read catalog
cat=read_delim(path_to_ATAC_catalog,delim='\t')
cat=as.data.frame(cat)
colnames(cat)=gsub(' ','_',colnames(cat))
cat$Disease_Type=ifelse(cat$Disease_Type=='PKD','ccRCC',cat$Disease_Type)

cat$Piece_ID=paste(cat$Disease_Type,cat$Piece_ID,sep='_')
cat=cat %>% dplyr::select ('Piece_ID','Sample_Type')
colnames(cat)[2]=c('Sample_type')
# Out:
# Rows: 225 Columns: 12
# ── Column specification ───────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (10): Disease Type, Sample ID, Case ID, Piece_ID, Sample Type, Data Type...
# lgl  (2): Include in the downstream analysis, Include in immune
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#Read average accessibility matrix
tab_1=fread(path_to_ATAC_average_matrix)
tab_1=as.data.frame(tab_1)
rownames(tab_1)=tab_1[,1]
tab_1=tab_1[,-1]
tab=tab_1
# Out:
# Warning message in fread(path_to_ATAC_average_matrix):
# “Detected 245 column names but the data has 246 columns (i.e. invalid file). Added 1 extra default column name for the first column which is guessed to be row names or an index. Use setnames() afterwards if this guess is not correct, or fix the file write command that created the file to create a valid file.”

# %%
#Remove cell groups with too few number of cells
meta=read.table(path_to_ATAC_average_matrix_meta,sep='\t',header=T)
meta$Cell_type=gsub(' ','-',meta$Cell_type)
meta_s=meta[meta$Cell_count>=20 ,]
colnames(tab)=gsub('\\.','-',colnames(tab))

# %%
#Add row annotation
tab=t(tab)
rownames(tab)=gsub(' ','-',rownames(tab))
tab=tab[rownames(tab) %in% meta_s$Cell_type,]

row_annot=as.data.frame(rownames(tab))
colnames(row_annot)='ID'
row_annot$Cell_type=gsub('(.*)__(.*)_(.*)','\\1',row_annot$ID)
row_annot$Cell_type=gsub('(.*)__(.*)','\\2',row_annot$Cell_type)
row_annot$Disease=gsub('(.*)__(.*)_(.*)','\\2',row_annot$ID)
row_annot$Disease=gsub('(.*)__(.*)','\\1',row_annot$Disease)

row_annot$Piece_ID=gsub('Tumor__','',row_annot$ID)
row_annot$Disease=gsub('(.*)_.*','\\1',row_annot$Disease)

#Annotate BRCA basal samples
row_annot$Disease=ifelse(row_annot$ID %in% 
                         paste('Tumor__BRCA',c("HT029B1-S1PC","HT035B1-S1PA","HT141B1-S1H1","HT206B1-S1H4","HT1408-06","HT268B1-Th1H3","HT271B1-S1H3","HT378B1-S1H1", "HT378B1-S1H2", "HT384B1-S1H1", "HT517B1-S1H1"),sep='_'),
                         'BRCA_Basal',row_annot$Disease)

rownames(row_annot)=row_annot$ID

row_annot=merge(row_annot, cat,all.x=T)
rownames(row_annot)=row_annot$ID

tab=tab[rownames(row_annot),]

# %%
#Read DACRs that were plotted in 1d:
sel_peaks=read_delim(path_to_ATAC_DACRs_1d, delim='\t',
                    show_col_types = FALSE)
sel_peaks=as.data.frame(sel_peaks)

supp=row_annot

#Subset data for tumor cells only
supp=supp[supp$Cell_type=='Tumor',]

#Make accessibility matrix with only those selected DACR (rows), and only those selected tumors (columns)
tab_t=as.data.frame(tab[rownames(supp),unique(sel_peaks$peak)])

# %%
#Run Rtsne
tab_t=as.matrix(tab_t)

set.seed(3)
x=Rtsne(tab_t,dims = 2, perplexity=30, verbose=TRUE, max_iter = 10000,learning=200,pca_scale=T)
to_plot=as.data.frame(x$Y)
to_plot$Disease=supp$Disease
to_plot$Case=supp$Piece_ID
to_plot$Disease=ifelse(to_plot$Case %in% c('CESC_CE332E1-N1','CESC_CE336E1-S1','CESC_CE354E1-S1','CESC_CE357E1-S1','CESC_CE507-C1A2'),"CEAD",to_plot$Disease)
to_plot$Sample_type=supp$Sample_type
# Out:
# Performing PCA
# Read the 201 x 50 data matrix successfully!
# Using no_dims = 2, perplexity = 30.000000, and theta = 0.500000
# Computing input similarities...
# Building tree...
# Done in 0.01 seconds (sparsity = 0.639390)!
# Learning embedding...
# Iteration 50: error is 52.238412 (50 iterations in 0.01 seconds)
# Iteration 100: error is 52.724147 (50 iterations in 0.01 seconds)
# Iteration 150: error is 53.429529 (50 iterations in 0.01 seconds)
# Iteration 200: error is 52.611178 (50 iterations in 0.01 seconds)
# Iteration 250: error is 52.472664 (50 iterations in 0.01 seconds)
# Iteration 300: error is 0.494352 (50 iterations in 0.01 seconds)
# Iteration 350: error is 0.188459 (50 iterations in 0.01 seconds)
# Iteration 400: error is 0.177810 (50 iterations in 0.01 seconds)
# Iteration 450: error is 0.177219 (50 iterations in 0.01 seconds)
# Iteration 500: error is 0.179612 (50 iterations in 0.01 seconds)
# Iteration 550: error is 0.178294 (50 iterations in 0.01 seconds)
# Iteration 600: error is 0.176543 (50 iterations in 0.01 seconds)
# Iteration 650: error is 0.174998 (50 iterations in 0.01 seconds)
# Iteration 700: error is 0.176208 (50 iterations in 0.01 seconds)
# Iteration 750: error is 0.176629 (50 iterations in 0.01 seconds)
# Iteration 800: error is 0.175616 (50 iterations in 0.01 seconds)
# Iteration 850: error is 0.175185 (50 iterations in 0.01 seconds)
# Iteration 900: error is 0.173955 (50 iterations in 0.01 seconds)
# Iteration 950: error is 0.174726 (50 iterations in 0.01 seconds)
# Iteration 1000: error is 0.173523 (50 iterations in 0.01 seconds)
# Iteration 1050: error is 0.174306 (50 iterations in 0.01 seconds)
# Iteration 1100: error is 0.174581 (50 iterations in 0.01 seconds)
# Iteration 1150: error is 0.174219 (50 iterations in 0.01 seconds)
# Iteration 1200: error is 0.174325 (50 iterations in 0.01 seconds)
# Iteration 1250: error is 0.174319 (50 iterations in 0.01 seconds)
# Iteration 1300: error is 0.174245 (50 iterations in 0.01 seconds)
# Iteration 1350: error is 0.174550 (50 iterations in 0.01 seconds)
# Iteration 1400: error is 0.174246 (50 iterations in 0.01 seconds)
# Iteration 1450: error is 0.173984 (50 iterations in 0.01 seconds)
# Iteration 1500: error is 0.174131 (50 iterations in 0.01 seconds)
# Iteration 1550: error is 0.173901 (50 iterations in 0.01 seconds)
# Iteration 1600: error is 0.173941 (50 iterations in 0.01 seconds)
# Iteration 1650: error is 0.174218 (50 iterations in 0.01 seconds)
# Iteration 1700: error is 0.173913 (50 iterations in 0.01 seconds)
# Iteration 1750: error is 0.174322 (50 iterations in 0.01 seconds)
# Iteration 1800: error is 0.173938 (50 iterations in 0.01 seconds)
# Iteration 1850: error is 0.173962 (50 iterations in 0.01 seconds)
# Iteration 1900: error is 0.173974 (50 iterations in 0.01 seconds)
# Iteration 1950: error is 0.173436 (50 iterations in 0.01 seconds)
# Iteration 2000: error is 0.174120 (50 iterations in 0.01 seconds)
# Iteration 2050: error is 0.172756 (50 iterations in 0.01 seconds)
# Iteration 2100: error is 0.173329 (50 iterations in 0.01 seconds)
# Iteration 2150: error is 0.173820 (50 iterations in 0.01 seconds)
# Iteration 2200: error is 0.174174 (50 iterations in 0.01 seconds)
# Iteration 2250: error is 0.174296 (50 iterations in 0.01 seconds)
# Iteration 2300: error is 0.174655 (50 iterations in 0.01 seconds)
# Iteration 2350: error is 0.174483 (50 iterations in 0.01 seconds)
# Iteration 2400: error is 0.174920 (50 iterations in 0.01 seconds)
# Iteration 2450: error is 0.176048 (50 iterations in 0.01 seconds)
# Iteration 2500: error is 0.174813 (50 iterations in 0.01 seconds)
# Iteration 2550: error is 0.175050 (50 iterations in 0.01 seconds)
# Iteration 2600: error is 0.175060 (50 iterations in 0.01 seconds)
# Iteration 2650: error is 0.175479 (50 iterations in 0.01 seconds)
# Iteration 2700: error is 0.175268 (50 iterations in 0.01 seconds)
# Iteration 2750: error is 0.175824 (50 iterations in 0.01 seconds)
# Iteration 2800: error is 0.175257 (50 iterations in 0.01 seconds)
# Iteration 2850: error is 0.175016 (50 iterations in 0.01 seconds)
# Iteration 2900: error is 0.175382 (50 iterations in 0.01 seconds)
# Iteration 2950: error is 0.175773 (50 iterations in 0.01 seconds)
# Iteration 3000: error is 0.175894 (50 iterations in 0.01 seconds)
# Iteration 3050: error is 0.175797 (50 iterations in 0.01 seconds)
# Iteration 3100: error is 0.175779 (50 iterations in 0.01 seconds)
# Iteration 3150: error is 0.175874 (50 iterations in 0.01 seconds)
# Iteration 3200: error is 0.175785 (50 iterations in 0.01 seconds)
# Iteration 3250: error is 0.174536 (50 iterations in 0.01 seconds)
# Iteration 3300: error is 0.174335 (50 iterations in 0.01 seconds)
# Iteration 3350: error is 0.174439 (50 iterations in 0.01 seconds)
# Iteration 3400: error is 0.175367 (50 iterations in 0.01 seconds)
# Iteration 3450: error is 0.174541 (50 iterations in 0.01 seconds)
# Iteration 3500: error is 0.175321 (50 iterations in 0.01 seconds)
# Iteration 3550: error is 0.175007 (50 iterations in 0.01 seconds)
# Iteration 3600: error is 0.175147 (50 iterations in 0.01 seconds)
# Iteration 3650: error is 0.174659 (50 iterations in 0.01 seconds)
# Iteration 3700: error is 0.174163 (50 iterations in 0.01 seconds)
# Iteration 3750: error is 0.173988 (50 iterations in 0.01 seconds)
# Iteration 3800: error is 0.173684 (50 iterations in 0.01 seconds)
# Iteration 3850: error is 0.174380 (50 iterations in 0.01 seconds)
# Iteration 3900: error is 0.173796 (50 iterations in 0.01 seconds)
# Iteration 3950: error is 0.173294 (50 iterations in 0.01 seconds)
# Iteration 4000: error is 0.174297 (50 iterations in 0.01 seconds)
# Iteration 4050: error is 0.173296 (50 iterations in 0.01 seconds)
# Iteration 4100: error is 0.174255 (50 iterations in 0.01 seconds)
# Iteration 4150: error is 0.173913 (50 iterations in 0.01 seconds)
# Iteration 4200: error is 0.173963 (50 iterations in 0.01 seconds)
# Iteration 4250: error is 0.174389 (50 iterations in 0.01 seconds)
# Iteration 4300: error is 0.174650 (50 iterations in 0.01 seconds)
# Iteration 4350: error is 0.173927 (50 iterations in 0.01 seconds)
# Iteration 4400: error is 0.173445 (50 iterations in 0.01 seconds)
# Iteration 4450: error is 0.173546 (50 iterations in 0.01 seconds)
# Iteration 4500: error is 0.172645 (50 iterations in 0.01 seconds)
# Iteration 4550: error is 0.174522 (50 iterations in 0.01 seconds)
# Iteration 4600: error is 0.173515 (50 iterations in 0.01 seconds)
# Iteration 4650: error is 0.173443 (50 iterations in 0.01 seconds)
# Iteration 4700: error is 0.173811 (50 iterations in 0.01 seconds)
# Iteration 4750: error is 0.173867 (50 iterations in 0.01 seconds)
# Iteration 4800: error is 0.174267 (50 iterations in 0.01 seconds)
# Iteration 4850: error is 0.173946 (50 iterations in 0.01 seconds)
# Iteration 4900: error is 0.174659 (50 iterations in 0.01 seconds)
# Iteration 4950: error is 0.172992 (50 iterations in 0.01 seconds)
# Iteration 5000: error is 0.174148 (50 iterations in 0.01 seconds)
# Iteration 5050: error is 0.174538 (50 iterations in 0.01 seconds)
# Iteration 5100: error is 0.174868 (50 iterations in 0.01 seconds)
# Iteration 5150: error is 0.174295 (50 iterations in 0.01 seconds)
# Iteration 5200: error is 0.173780 (50 iterations in 0.01 seconds)
# Iteration 5250: error is 0.174284 (50 iterations in 0.01 seconds)
# Iteration 5300: error is 0.174482 (50 iterations in 0.01 seconds)
# Iteration 5350: error is 0.174630 (50 iterations in 0.01 seconds)
# Iteration 5400: error is 0.174127 (50 iterations in 0.01 seconds)
# Iteration 5450: error is 0.174453 (50 iterations in 0.01 seconds)
# Iteration 5500: error is 0.174279 (50 iterations in 0.01 seconds)
# Iteration 5550: error is 0.174312 (50 iterations in 0.01 seconds)
# Iteration 5600: error is 0.174229 (50 iterations in 0.01 seconds)
# Iteration 5650: error is 0.174104 (50 iterations in 0.01 seconds)
# Iteration 5700: error is 0.174304 (50 iterations in 0.01 seconds)
# Iteration 5750: error is 0.173401 (50 iterations in 0.01 seconds)
# Iteration 5800: error is 0.173966 (50 iterations in 0.01 seconds)
# Iteration 5850: error is 0.173172 (50 iterations in 0.01 seconds)
# Iteration 5900: error is 0.174128 (50 iterations in 0.01 seconds)
# Iteration 5950: error is 0.173871 (50 iterations in 0.01 seconds)
# Iteration 6000: error is 0.174847 (50 iterations in 0.01 seconds)
# Iteration 6050: error is 0.174980 (50 iterations in 0.01 seconds)
# Iteration 6100: error is 0.174839 (50 iterations in 0.01 seconds)
# Iteration 6150: error is 0.174822 (50 iterations in 0.01 seconds)
# Iteration 6200: error is 0.175044 (50 iterations in 0.01 seconds)
# Iteration 6250: error is 0.174846 (50 iterations in 0.01 seconds)
# Iteration 6300: error is 0.175027 (50 iterations in 0.01 seconds)
# Iteration 6350: error is 0.174534 (50 iterations in 0.01 seconds)
# Iteration 6400: error is 0.174181 (50 iterations in 0.01 seconds)
# Iteration 6450: error is 0.174275 (50 iterations in 0.01 seconds)
# Iteration 6500: error is 0.174175 (50 iterations in 0.01 seconds)
# Iteration 6550: error is 0.174151 (50 iterations in 0.01 seconds)
# Iteration 6600: error is 0.173757 (50 iterations in 0.01 seconds)
# Iteration 6650: error is 0.174313 (50 iterations in 0.01 seconds)
# Iteration 6700: error is 0.174370 (50 iterations in 0.01 seconds)
# Iteration 6750: error is 0.174424 (50 iterations in 0.01 seconds)
# Iteration 6800: error is 0.174235 (50 iterations in 0.01 seconds)
# Iteration 6850: error is 0.174683 (50 iterations in 0.01 seconds)
# Iteration 6900: error is 0.174694 (50 iterations in 0.01 seconds)
# Iteration 6950: error is 0.174526 (50 iterations in 0.01 seconds)
# Iteration 7000: error is 0.174390 (50 iterations in 0.01 seconds)
# Iteration 7050: error is 0.174701 (50 iterations in 0.01 seconds)
# Iteration 7100: error is 0.174934 (50 iterations in 0.01 seconds)
# Iteration 7150: error is 0.174656 (50 iterations in 0.01 seconds)
# Iteration 7200: error is 0.174950 (50 iterations in 0.01 seconds)
# Iteration 7250: error is 0.174773 (50 iterations in 0.01 seconds)
# Iteration 7300: error is 0.175094 (50 iterations in 0.01 seconds)
# Iteration 7350: error is 0.175043 (50 iterations in 0.01 seconds)
# Iteration 7400: error is 0.174902 (50 iterations in 0.01 seconds)
# Iteration 7450: error is 0.175055 (50 iterations in 0.01 seconds)
# Iteration 7500: error is 0.174879 (50 iterations in 0.01 seconds)
# Iteration 7550: error is 0.174675 (50 iterations in 0.01 seconds)
# Iteration 7600: error is 0.174850 (50 iterations in 0.01 seconds)
# Iteration 7650: error is 0.174849 (50 iterations in 0.01 seconds)
# Iteration 7700: error is 0.174794 (50 iterations in 0.01 seconds)
# Iteration 7750: error is 0.175088 (50 iterations in 0.01 seconds)
# Iteration 7800: error is 0.174640 (50 iterations in 0.01 seconds)
# Iteration 7850: error is 0.174821 (50 iterations in 0.01 seconds)
# Iteration 7900: error is 0.174301 (50 iterations in 0.01 seconds)
# Iteration 7950: error is 0.174451 (50 iterations in 0.01 seconds)
# Iteration 8000: error is 0.175280 (50 iterations in 0.01 seconds)
# Iteration 8050: error is 0.174908 (50 iterations in 0.01 seconds)
# Iteration 8100: error is 0.174077 (50 iterations in 0.01 seconds)
# Iteration 8150: error is 0.174533 (50 iterations in 0.01 seconds)
# Iteration 8200: error is 0.174695 (50 iterations in 0.01 seconds)
# Iteration 8250: error is 0.174799 (50 iterations in 0.01 seconds)
# Iteration 8300: error is 0.174263 (50 iterations in 0.01 seconds)
# Iteration 8350: error is 0.174869 (50 iterations in 0.01 seconds)
# Iteration 8400: error is 0.174592 (50 iterations in 0.01 seconds)
# Iteration 8450: error is 0.174730 (50 iterations in 0.01 seconds)
# Iteration 8500: error is 0.174641 (50 iterations in 0.01 seconds)
# Iteration 8550: error is 0.174841 (50 iterations in 0.01 seconds)
# Iteration 8600: error is 0.174328 (50 iterations in 0.01 seconds)
# Iteration 8650: error is 0.174660 (50 iterations in 0.01 seconds)
# Iteration 8700: error is 0.174246 (50 iterations in 0.01 seconds)
# Iteration 8750: error is 0.174025 (50 iterations in 0.01 seconds)
# Iteration 8800: error is 0.173973 (50 iterations in 0.01 seconds)
# Iteration 8850: error is 0.174033 (50 iterations in 0.01 seconds)
# Iteration 8900: error is 0.173715 (50 iterations in 0.01 seconds)
# Iteration 8950: error is 0.173870 (50 iterations in 0.01 seconds)
# Iteration 9000: error is 0.173437 (50 iterations in 0.01 seconds)
# Iteration 9050: error is 0.173564 (50 iterations in 0.01 seconds)
# Iteration 9100: error is 0.174037 (50 iterations in 0.01 seconds)
# Iteration 9150: error is 0.174380 (50 iterations in 0.01 seconds)
# Iteration 9200: error is 0.174129 (50 iterations in 0.01 seconds)
# Iteration 9250: error is 0.173819 (50 iterations in 0.01 seconds)
# Iteration 9300: error is 0.174281 (50 iterations in 0.01 seconds)
# Iteration 9350: error is 0.174093 (50 iterations in 0.01 seconds)
# Iteration 9400: error is 0.173890 (50 iterations in 0.01 seconds)
# Iteration 9450: error is 0.173506 (50 iterations in 0.01 seconds)
# Iteration 9500: error is 0.174640 (50 iterations in 0.01 seconds)
# Iteration 9550: error is 0.174093 (50 iterations in 0.01 seconds)
# Iteration 9600: error is 0.174581 (50 iterations in 0.01 seconds)
# Iteration 9650: error is 0.174026 (50 iterations in 0.01 seconds)
# Iteration 9700: error is 0.173164 (50 iterations in 0.01 seconds)
# Iteration 9750: error is 0.174031 (50 iterations in 0.01 seconds)
# Iteration 9800: error is 0.173648 (50 iterations in 0.01 seconds)
# Iteration 9850: error is 0.173564 (50 iterations in 0.01 seconds)
# Iteration 9900: error is 0.173452 (50 iterations in 0.01 seconds)
# Iteration 9950: error is 0.173451 (50 iterations in 0.01 seconds)
# Iteration 10000: error is 0.173328 (50 iterations in 0.01 seconds)
# Fitting performed in 1.75 seconds.

# %% [markdown]
# ## Do plotting

# %%
options(ggrepel.max.overlaps = Inf)

plot <- ggplot(data=to_plot)

plot <- plot + geom_point(aes(x=V1,y=V2,color=Disease,shape=Sample_type))

plot <- plot + scale_color_manual(values=dis_cols_ed)

plot <- plot + ylab("tSNE_2") +xlab("tSNE_1")

plot <- plot + theme_classic()

plot <- plot + scale_shape_manual(values=c('Tumor'=15,'Met'=16))

# %%
options(repr.plot.width=8, repr.plot.height=7)
plot
# Out:
# plot without title
